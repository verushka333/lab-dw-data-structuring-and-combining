# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd

# %%
insurance = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv')

# %%
insurance_1 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv')

# %%
insurance_2 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv').rename(columns = {'State':'ST', 'Gender':'GENDER'})

# %%
insurance.head(1)
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  RB50392  Washington    NaN    Master                     NaN     0.0
#
#    Monthly Premium Auto Number of Open Complaints    Policy Type  \
# 0                1000.0                    1/0/00  Personal Auto
#
#    Vehicle Class  Total Claim Amount
# 0  Four-Door Car            2.704934

# %%
insurance_1.head(1)
# Out:
#   Customer       ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873  Arizona      F  Bachelor              323912.47%   16061
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
#
#      Policy Type  Vehicle Class
# 0  Personal Auto  Four-Door Car

# %%
insurance_2.head(1)
# Out:
#   Customer          ST  Customer Lifetime Value             Education GENDER  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
#
#    Total Claim Amount Vehicle Class
# 0               499.2  Two-Door Car

# %%
insurance_total = pd.concat([insurance,insurance_1,insurance_2],axis=0)

# %%
insurance_total
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
insurance_analysis = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv')

# %%
insurance_analysis
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
insurance_analysis.set_index('unnamed:_0')
insurance_analysis.drop(columns='unnamed:_0')
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  California              6857.519928       No     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
insurance_analysis.dtypes
# Out:
# unnamed:_0                         int64
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# ...

# %%
insurance_analysis = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv',index_col=0)
insurance_analysis.head()
# Out:
#            customer       state  customer_lifetime_value response  coverage  \
# unnamed:_0
# 0           DK49336     Arizona              4809.216960       No     Basic
# 1           KX64629  California              2228.525238       No     Basic
# 2           LZ68649  Washington             14947.917300       No     Basic
# 3           XL78013      Oregon             22332.439460      Yes  Extended
# 4           QA50777      Oregon              9025.067525       No   Premium
#
#            education effective_to_date employmentstatus gender  income  ...  \
# unnamed:_0                                                              ...
# 0            College        2011-02-18         Employed      M   48029  ...
# 1            College        2011-01-18       Unemployed      F       0  ...
# 2           Bachelor        2011-02-10         Employed      M   22139  ...
# 3            College        2011-01-11         Employed      M   49078  ...
# ...

# %%
insurance_analysis.describe(include='all').round(2)
# Out:
#        customer       state  customer_lifetime_value response coverage  \
# count     10910       10910                 10910.00    10910    10910
# unique     9134           5                      NaN        2        3
# top     ID89933  California                      NaN       No    Basic
# freq          7        4183                      NaN     9444     6660
# mean        NaN         NaN                  8018.24      NaN      NaN
# std         NaN         NaN                  6885.08      NaN      NaN
# min         NaN         NaN                  1898.01      NaN      NaN
# 25%         NaN         NaN                  4014.45      NaN      NaN
# 50%         NaN         NaN                  5771.15      NaN      NaN
# 75%         NaN         NaN                  8992.78      NaN      NaN
# max         NaN         NaN                 83325.38      NaN      NaN
#
#        education effective_to_date employmentstatus gender    income  ...  \
# ...

# %%
insurance_analysis.dropna(axis=1,thresh=20,inplace=True)

# %%
insurance_analysis['total_revenue'] = insurance_analysis['monthly_premium_auto']*insurance_analysis['months_since_policy_inception']*insurance_analysis['number_of_policies']

# %%
pd.pivot_table(insurance_analysis,index='sales_channel',values='customer_lifetime_value',aggfunc='sum').round(2)
# Out:
#                customer_lifetime_value
# sales_channel
# Agent                      33057887.85
# Branch                     24359201.21
# Call Center                17364288.37
# Web                        12697632.90

# %%
insurance_analysis['policy'].unique()
# Out:
# array(['Corporate L3', 'Personal L3', 'Personal L2', 'Corporate L2',
#        'Personal L1', 'Special L1', 'Corporate L1', 'Special L3',
#        'Special L2'], dtype=object)

# %%
pd.pivot_table(insurance_analysis,index='sales_channel',values='monthly_premium_auto',aggfunc='sum').round(2)
# Out:
#                monthly_premium_auto
# sales_channel
# Agent                        386335
# Branch                       280953
# Call Center                  197970
# Web                          151511

# %%
pd.pivot_table(insurance_analysis,index='sales_channel',values='total_revenue',aggfunc='sum').round(2)
# Out:
#                total_revenue
# sales_channel
# Agent               53903710
# Branch              40082086
# Call Center         27235765
# Web                 23720513

# %%
insurance_analysis.groupby('sales_channel')[['total_revenue']].sum().round
# Out:
# <bound method DataFrame.round of                total_revenue
# sales_channel
# Agent               53903710
# Branch              40082086
# Call Center         27235765
# Web                 23720513>

# %%
insurance_analysis.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size', 'vehicle_type', 'month',
#        'total_revenue'],
#       dtype='object')

# %%
pd.pivot_table(insurance_analysis,index='gender',columns='education',values='customer_lifetime_value',aggfunc='mean')
# Out:
# education     Bachelor      College       Doctor  High School or Below  \
# gender
# F          7874.269478  7748.823325  7328.508916           8675.220201
# M          7703.601675  8052.459288  7415.333638           8149.687783
#
# education       Master
# gender
# F          8157.053154
# M          8168.832659

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
insurance_analysis
# Out:
#            customer       state  customer_lifetime_value response  coverage  \
# unnamed:_0
# 0           DK49336     Arizona              4809.216960       No     Basic
# 1           KX64629  California              2228.525238       No     Basic
# 2           LZ68649  Washington             14947.917300       No     Basic
# 3           XL78013      Oregon             22332.439460      Yes  Extended
# 4           QA50777      Oregon              9025.067525       No   Premium
# ...             ...         ...                      ...      ...       ...
# 10905       FE99816      Nevada             15563.369440       No   Premium
# 10906       KX53892      Oregon              5259.444853       No     Basic
# 10907       TL39050     Arizona             23893.304100       No  Extended
# 10908       WA60547  California             11971.977650       No   Premium
# 10909       IV32877  California              6857.519928       No     Basic
#
# ...

# %%
sorted(insurance_analysis.columns)
# Out:
# ['coverage',
#  'customer',
#  'customer_lifetime_value',
#  'education',
#  'effective_to_date',
#  'employmentstatus',
#  'gender',
#  'income',
#  'location_code',
#  'marital_status',
#  'month',
#  'monthly_premium_auto',
#  'months_since_last_claim',
#  'months_since_policy_inception',
#  'number_of_open_complaints',
#  'number_of_policies',
#  'policy',
#  'policy_type',
#  'renew_offer_type',
#  'response',
#  'sales_channel',
#  'state',
#  'total_claim_amount',
#  'total_revenue',
#  'vehicle_class',
#  'vehicle_size',
#  'vehicle_type']

# %%
insurance_analysis_melt = insurance_analysis.melt(id_vars=['policy_type','number_of_open_complaints'],value_vars=['month'],var_name='month', value_name='Amount')
insurance_analysis_melt
# Out:
#           policy_type  number_of_open_complaints  month  Amount
# 0      Corporate Auto                   0.000000  month       2
# 1       Personal Auto                   0.000000  month       1
# 2       Personal Auto                   0.000000  month       2
# 3      Corporate Auto                   0.000000  month       1
# 4       Personal Auto                   0.384256  month       1
# ...               ...                        ...    ...     ...
# 10905   Personal Auto                   0.384256  month       1
# 10906   Personal Auto                   0.000000  month       1
# 10907  Corporate Auto                   0.000000  month       2
# 10908   Personal Auto                   4.000000  month       2
# 10909   Personal Auto                   0.000000  month       1
#
# [10910 rows x 4 columns]

# %%
insurance_analysis[['policy_type','number_of_open_complaints','month']]
# Out:
#                policy_type  number_of_open_complaints  month
# unnamed:_0
# 0           Corporate Auto                   0.000000      2
# 1            Personal Auto                   0.000000      1
# 2            Personal Auto                   0.000000      2
# 3           Corporate Auto                   0.000000      1
# 4            Personal Auto                   0.384256      1
# ...                    ...                        ...    ...
# 10905        Personal Auto                   0.384256      1
# 10906        Personal Auto                   0.000000      1
# 10907       Corporate Auto                   0.000000      2
# 10908        Personal Auto                   4.000000      2
# 10909        Personal Auto                   0.000000      1
#
# [10910 rows x 3 columns]

# %%
pd.pivot_table(insurance_analysis,index='policy_type',columns='month',values='number_of_open_complaints',aggfunc='sum') #wide
# Out:
# month                     1            2
# policy_type
# Corporate Auto   443.434952   385.208135
# Personal Auto   1727.605722  1453.684441
# Special Auto      87.074049    95.226817

# %%
pd.pivot_table(insurance_analysis,index=['policy_type','month'],values='number_of_open_complaints',aggfunc='sum') #long
# Out:
#                       number_of_open_complaints
# policy_type    month
# Corporate Auto 1                     443.434952
#                2                     385.208135
# Personal Auto  1                    1727.605722
#                2                    1453.684441
# Special Auto   1                      87.074049
#                2                      95.226817
